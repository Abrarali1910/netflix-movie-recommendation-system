# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("/content/Book2.csv")
print(data)
# Out:
#           Movie      Genre
# 0      Avengers     Action
# 1      Iron Man     Action
# 2        Batman     Action
# 3       Titanic   Romantic
# 4      Notebook   Romantic
# 5    La La Land   Romantic
# 6   Intersellar     Sci-Fi
# 7       Gravity     Sci-Fi
# 8   The Martian    Sci-fFI
# 9        Frozen  Animation
# 10    Toy Story  Animation
# 11         Coco  Animation

# %%
encoder = LabelEncoder()
data["Genre_encoded"] = encoder.fit_transform(data["Genre"])
print(data)
# Out:
#           Movie      Genre  Genre_encoded
# 0      Avengers     Action              0
# 1      Iron Man     Action              0
# 2        Batman     Action              0
# 3       Titanic   Romantic              2
# 4      Notebook   Romantic              2
# 5    La La Land   Romantic              2
# 6   Intersellar     Sci-Fi              3
# 7       Gravity     Sci-Fi              3
# 8   The Martian    Sci-fFI              4
# 9        Frozen  Animation              1
# 10    Toy Story  Animation              1
# 11         Coco  Animation              1

# %%
similarity = cosine_similarity(data[["Genre_encoded"]])

# %%
def recommended_movies(movie_name):
    movie_index = data[data["Movie"] == movie_name].index[0]
    similarity_scores = list(enumerate(similarity[movie_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    print("Recommended Movies:")
    for i in similarity_scores [1:4]:
        print(data.iloc[i[0]]["Movie"])

# %%
recommended_movies("Avengers")
# Out:
# Recommended Movies:
# Iron Man
# Batman
# Titanic
